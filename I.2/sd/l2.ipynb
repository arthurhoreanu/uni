# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*x*y
desolve(eqd,y)
# Out:
# _C*e^(x^2)

# %%
x=var('x')
_C=var('_C')
y=function('y')(x)
eqd=diff(y,x)==2*x*y
sol=desolve(eqd,y)
sol1=sol.substitute(_C==1)
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==y/x
desolve(eqd,y)
# Out:
# _C*x

# %%
x=var('x')
_C=var('_C')
y=function('y')(x)
eqd=diff(y,x)==y/x
sol=desolve(eqd,y)
sol1=sol.substitute(_C==1)
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==(2*x)*(1+y^2)
desolve(eqd,y)
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
yy=var('yy')
_C=var('_C')
sol1(x, yy, _C)=1/2*arctan(yy) == 1/2*x^2 + _C
implicit_plot(sol1(x,yy,0),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=(x^2-1)*diff(y,x)+2*x*y^2==0
desolve(eqd,y)
# Out:
# 1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1)

# %%
yy=var('yy')
_C=var('_C')
sol1(x, yy, _C)=1/2/yy == _C + 1/2*log(x + 1) + 1/2*log(x - 1)
implicit_plot(sol1(x,yy,0),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+y*tan(x)==1/cos(x)
desolve(eqd,y)
# Out:
# (_C + tan(x))/sec(x)

# %%
x=var('x')
_C=var('_C')
y=function('y')(x)
eqd=diff(y,x)+y*tan(x)==1/cos(x)
sol=desolve(eqd,y)
sol1=sol.substitute(_C==1)
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+(2/x)*y==x^3
desolve(eqd,y)
# Out:
# 1/6*(x^6 + 6*_C)/x^2

# %%
x=var('x')
_C=var('_C')
y=function('y')(x)
eqd=diff(y,x)+(2/x)*y==x^3
sol=desolve(eqd,y)
sol1=sol.substitute(_C==1)
plot(sol1,x,-10,10,ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)+(1/x)*y==3*x
desolve(eqd,y)
# Out:
# (x^3 + _C)/x

# %%
x=var('x')
_C=var('_C')
y=function('y')(x)
eqd=diff(y,x)+(1/x)*y==3*x
sol=desolve(eqd,y)
sol1=sol.substitute(_C==1)
plot(sol1,x,-10,10,ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1+y^2
sol=desolve(eqd,y,ics=[0,1])
sol
# Out:
# arctan(y(x)) == 1/4*pi + x

# %%
yy=var('yy')
_C=var('_C')
sol1(x, yy, _C)=arctan(yy) == 1/4*pi + x
implicit_plot(sol1(x,yy),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==-x^2+2*y
sol=desolve(eqd,y,ics=[0,1/4])
sol
# Out:
# 1/2*x^2 + 1/2*x + 1/4

# %%
_C=var('_C')
sol1(x, _C)=arctan(yy) == 1/2*x^2 + 1/2*x + 1/4
implicit_plot(sol1(x,yy),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1/cos(x)-y*tan(x)
sol=desolve(eqd,y,ics=[0,0])
sol
# Out:
# tan(x)/sec(x)

# %%
yy=var('yy')
_C=var('_C')
sol1(x, yy, _C)=arctan(yy) == tan(x)/sec(x)
implicit_plot(sol1(x,yy),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
k = var('k')
y = function('y')(x)
eq = diff(y,x) == x^3 - y*k/x
sol = desolve(eq, [y,x])
sol
# Out:
# (x^4*x^k/(k + 4) + _C)/x^k

# %%
x=var('x')
_C=var('_C')
y=function('y')(x)
eqd = diff(y,x) == x^3 - y*1/x
sol=desolve(eqd,y)
sol1=sol.substitute(_C==1)
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd = diff(y,x) == x^3 - y*1/x
sol=desolve(eqd,y,ics=[1,0])
sol
# Out:
# 1/5*(x^5 - 1)/x

# %%
yy=var('yy')
_C=var('_C')
sol1(x, yy, _C)=arctan(yy) == 1/5*(x^5 - 1)/x
implicit_plot(sol1(x,yy),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd = diff(y,x) == x^3 - y*10/x
sol=desolve(eqd,y,ics=[1,0])
sol
# Out:
# 1/14*(x^14 - 1)/x^10

# %%
yy=var('yy')
_C=var('_C')
sol1(x, yy, _C)=arctan(yy) == 1/14*(x^14 - 1)/x^10
implicit_plot(sol1(x,yy),(x,-5,5),(yy,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
k = var('k')
y = function('y')(x)
eq = diff(y,x) == cos(x)+(1/2)*y
sol = desolve(eq, y)
sol
# Out:
# -1/5*(2*(cos(x) - 2*sin(x))*e^(-1/2*x) - 5*_C)*e^(1/2*x)

# %%
x=var('x')
_C=var('_C')
y=function('y')(x)
eqd = diff(y,x) == cos(x)+(1/2)*y
sol=desolve(eqd,y)
sol1=sol.substitute(_C==1)
plot(sol1,x,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
a=var('a')
y=function('y')(x)
eqd = diff(y,x) == cos(x)+(1/2)*y
sol=desolve(eqd,y,ics=[0,a])
sol
# Out:
# 1/5*(5*a + 2)*e^(1/2*x) - 2/5*cos(x) + 4/5*sin(x)
