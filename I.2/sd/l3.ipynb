# %%
_K1=var('_K1')
_K2=var('_K2')
eq = diff(y,x,2) + y == sin(x) + cos(x)
sol1(x, _K1, _K2)=desolve(eq, y)
plot(sol1(x,1,2), x, -10, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eq = diff(y,x,2) - y == e^(2*x)
sol = desolve(eq, y)
sol
# Out:
# _K2*e^(-x) + _K1*e^x + 1/3*e^(2*x)

# %%
_K1=var('_K1')
_K2=var('_K2')
eq = diff(y,x,2) - y == e^(2*x)
sol1(x, _K1, _K2)=desolve(eq, y)
plot(sol1(x,1,2), x, -10, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
y = function('y')(x)
eq = diff(y,x,2) + 4*y == 1/cos(2*x)
sol = desolve(eq, y)
sol
# Out:
# _K2*cos(2*x) + 1/4*cos(2*x)*log(cos(2*x)) + _K1*sin(2*x) + 1/2*x*sin(2*x)

# %%
x = var('x')
y = function('y')(x)
eq = diff(y,x,2) - diff(y,x) == 1/(1+e^x)
sol = desolve(eq, y)
sol
# Out:
# _K1*e^x + e^x*log((e^x + 1)*e^(-x)) + _K2 - x + log(e^x + 1)
