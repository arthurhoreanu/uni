# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
sol_x
g1=plot(sol_x(t,1,1),t,-4,4,ymin=-10,ymax=10,color='red')
g2=plot(sol_y(t,1,1),t,-4,4,ymin=-10,ymax=10,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==2*x-y
deq2=diff(y,t)==x+2*y
syst=[deq1,deq2]
# desolve_system(syst, [x,y])
C1,C2=var('C1,C2')
desolve_system(syst, [x,y],[0,C1,C2])
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
sol_x
g1=plot(sol_x(t,1,1),t,-4,4,ymin=-10,ymax=10,color='red')
g2=plot(sol_y(t,1,1),t,-4,4,ymin=-10,ymax=10,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-y+z
deq2=diff(y,t)==x+y-z
deq3=diff(z,t)==-y+2*z
syst=[deq1,deq2,deq3]
C1,C2,C3=var('C1,C2,C3')
sol=desolve_system(syst, [x,y,z],[0,C1,C2,C3])
sol_x(t,C1,C2,C3)=sol[0].rhs()
sol_y(t,C1,C2,C3)=sol[1].rhs()
sol_z(t,C1,C2,C3)=sol[2].rhs()
g1=plot(sol_x(t,1,1,3),t,-4,4,ymin=-10,ymax=10,color='red')
g2=plot(sol_y(t,1,4,1),t,-4,4,ymin=-10,ymax=10,color='blue')
g3=plot(sol_z(t,1,1,2),t,-4,4,ymin=-10,ymax=10,color='yellow')
show(g1+g2+g3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==5*x+3*y+1
deq2=diff(y,t)==-6*x-4*y+e**-t
syst=[deq1,deq2]
C1,C2=var('C1,C2')
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2,C3)=sol[0].rhs()
sol_y(t,C1,C2,C3)=sol[1].rhs()
g1=plot(sol_x(t,1,1,3),t,-4,4,ymin=-10,ymax=10,color='red')
g2=plot(sol_y(t,1,4,1),t,-4,4,ymin=-10,ymax=10,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]
sol=desolve_system(syst, vars,in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot(sol_x(t),t,-4,4,ymin=-10,ymax=10,color='red')
g2=plot(sol_y(t),t,-4,4,ymin=-10,ymax=10,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x-y+t-1
deq2=diff(y,t)==-2*x + 4*y +cos(t)
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]
sol=desolve_system(syst, vars,in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot(sol_x(t),t,-40,40,ymin=-10,ymax=10,color='red')
g2=plot(sol_y(t),t,-40,40,ymin=-10,ymax=10,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+2*y+e**-t
deq2=diff(y,t)==-2*x + y + 1
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]
sol=desolve_system(syst, vars,in_cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot(sol_x(t),t,-40,40,ymin=-10,ymax=10,color='red')
g2=plot(sol_y(t),t,-40,40,ymin=-10,ymax=10,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==y
deq2=diff(y,t)==-x -2*y
syst=[deq1,deq2]
C1,C2=var('C1,C2')
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2,C3)=sol[0].rhs()
sol_y(t,C1,C2,C3)=sol[1].rhs()
sol_x
sol_y
# Out:
# (t, C1, C2, C3) |--> -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)

# %%
limit(sol_x(t,C1,C2,C3),t=infinity)
# Out:
# 0

# %%
limit(sol_y(t,C1,C2,C3),t=infinity)
# Out:
# 0

# %%
f1(u,v)=v
f2(u,v)=-u-2*v
plot_vector_field( [f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u,v)=2*u+v
f2(u,v)=u+2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u,v)=v
f2(u,v)=-u
n=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u,v)=-2*u
f2(u,v)=-4*u-2*v
n=sqrt(f1(u,v)^2+f2(u,v)^2)
plot_vector_field( [f1(u,v)/n,f2(u,v)/n], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x
